# %% [markdown]
# #Análise dos dados do reembolso dos senadores - 2019

# %%
import pandas as pd

# %%
#carregar o arquivo csv
df = pd.read_csv('2019.csv', sep=';', encoding='latin1', skiprows=1, decimal=',')

df.head()
# Out:
#     ANO  MES       SENADOR                                       TIPO_DESPESA  \
# 0  2019    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 1  2019    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 2  2019    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 3  2019    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 4  2019    2  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
#
#              CNPJ_CPF                                FORNECEDOR  DOCUMENTO  \
# 0  05.914.650/0001-66  ELETROBRÁS DISTRIBUIÇÃO RONDÔNIA - CERON  006582758
# 1  05.914.650/0001-66  ELETROBRÁS DISTRIBUIÇÃO RONDÔNIA - CERON  006582755
# 2      004.948.028-63             GILBERTO PISELO DO NASCIMENTO      00119
# 3  05.423.963/0001-11                             OI MÓVEL S.A.   86161151
# 4  05.914.650/0001-66  ELETROBRÁS DISTRIBUIÇÃO RONDÔNIA - CERON  007236036
#
# ...

# %%
#Quantos reembolsos foram solicitados por cada senador?
df['SENADOR'].value_counts()
# Out:
# HUMBERTO COSTA                   446
# TELMÁRIO MOTA                    414
# CARLOS VIANA                     380
# JOSÉ SERRA                       372
# MAJOR OLIMPIO                    366
# ZEQUINHA MARINHO                 360
# PAULO PAIM                       350
# WELLINGTON FAGUNDES              339
# LUIS CARLOS HEINZE               312
# FLÁVIO ARNS                      284
# ESPERIDIÃO AMIN                  268
# MARA GABRILLI                    267
# CONFÚCIO MOURA                   267
# MAILZA GOMES                     264
# PAULO ROCHA                      252
# JAQUES WAGNER                    250
# JARBAS VASCONCELOS               247
# JUÍZA SELMA                      243
# ELMANO FÉRRER                    242
# ANTONIO ANASTASIA                239
# ROGÉRIO CARVALHO                 237
# FABIANO CONTARATO                224
# JEAN PAUL PRATES                 220
# FERNANDO BEZERRA COELHO          217
# DANIELLA RIBEIRO                 208
# ...

# %%
#Quanto cada senador solicitou de reembolso em 2018?
df.groupby('SENADOR')['VALOR_REEMBOLSADO'].sum().sort_values(ascending=False)
# Out:
# SENADOR
# OMAR AZIZ                        360653.50
# EDUARDO BRAGA                    336512.42
# PAULO ROCHA                      318470.18
# TELMÁRIO MOTA                    312612.50
# MAILZA GOMES                     297823.26
# HUMBERTO COSTA                   287186.77
# ELMANO FÉRRER                    282964.83
# JARBAS VASCONCELOS               282509.76
# ZEQUINHA MARINHO                 279372.46
# ALESSANDRO VIEIRA                263773.27
# ELIZIANE GAMA                    255683.67
# ROMÁRIO                          255622.21
# ROBERTO ROCHA                    253201.04
# ROGÉRIO CARVALHO                 249998.41
# RANDOLFE RODRIGUES               235974.71
# MECIAS DE JESUS                  234107.04
# MARCELO CASTRO                   229187.64
# FERNANDO BEZERRA COELHO          225209.61
# JADER BARBALHO                   223018.22
# ZENAIDE MAIA                     222703.52
# PAULO PAIM                       222115.66
# JORGINHO MELLO                   220177.54
# ...
