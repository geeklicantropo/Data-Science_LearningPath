# %% [markdown]
# #Análise dos dados da API dos partidos Análise dos dados obtidos pela API da câmara dos deputados

# %%
import pandas as pd

# %%
#carregar o arquivo csv
df = pd.read_csv('Ano-2019.csv', sep=';', encoding='latin1')

df.head()
# Out:
#   txNomeParlamentar  ideCadastro  nuCarteiraParlamentar  nuLegislatura sgUF  \
# 0            AVANTE          NaN                    NaN           2019  NaN
# 1            AVANTE          NaN                    NaN           2019  NaN
# 2            AVANTE          NaN                    NaN           2019  NaN
# 3            AVANTE          NaN                    NaN           2019  NaN
# 4            AVANTE          NaN                    NaN           2019  NaN
#
#   sgPartido  codLegislatura  numSubCota  \
# 0       NaN              56          13
# 1       NaN              56          13
# 2       NaN              56          13
# 3       NaN              56          13
# 4       NaN              56          13
#
#                                    txtDescricao  numEspecificacaoSubCota  \
# 0  FORNECIMENTO DE ALIMENTAÃÃO DO PARLAMENTAR                        0
# 1  FORNECIMENTO DE ALIMENTAÃÃO DO PARLAMENTAR                        0
# ...
